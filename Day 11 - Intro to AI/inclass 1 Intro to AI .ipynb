# %% [markdown]
# # $$Artificial-Intelligence$$

# %% [markdown]
# -

# %% [markdown]
# Narrow AI
#
# General AI
#
# Super AI
#
#
# repetition of ai, ml, dl, genai
#
# ML
#
# process of ML
#
# Supervised Learning
#
# algorithms - Linear Regression
