# %%
import numpy as np
from scipy import stats

df['age_z'] = np.abs(stats.zscore(df['age']))
df['temp_z'] = np.abs(stats.zscore(df['temperature']))
df['amaount_z'] = np.abs(stats.zscore(df['amount']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import numpy as np
#       2 from scipy import stats
# ----> 4 df['age_z'] = np.abs(stats.zscore(df['age']))
#       5 df['temp_z'] = np.abs(stats.zscore(df['temperature']))
#       6 df['amaount_z'] = np.abs(stats.zscore(df['amount']))
#
# NameError: name 'df' is not defined

# %%
#df.drop(['age_z','temp_z', 'amaount_z'], axis=1, inplace = True)

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q1 + 1.5 * IQR

    df_clean2 = df
