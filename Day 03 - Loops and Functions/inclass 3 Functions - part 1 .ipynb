# %% [markdown]
# # $$Functions$$

# %% [markdown]
# - function is a reusable piece of code that performs a specific task
# - functions in maths ---> something that takes an input, and gives an output
# -
# -
# ```python
# # function syntax
#
# # function definition
# def function_name (parameters): # inputs that you want to take from the user later
#     # code that you want to reuse somewhere else
#
#     return result/output
#
# # function call
# function_name(arguments)

# %%
# function definition
def greet():
    print("Hellowwww!!!!")
    print("Hellowwww!!!!")
    print("Hellowwww!!!!")
    print("Hellowwww!!!!")

# %%
greet()
# Out:
# Hellowwww!!!!
# Hellowwww!!!!
# Hellowwww!!!!
# Hellowwww!!!!

# %%
# create a function that takes a name and greets that person

def greet( name, greeting):
    message = f"{greeting} {name}"
    return message

# %%
greet("idrees", "Salamat Petang")
# Out:
# 'Salamat Petang idrees'

# %%
# calculator function

# we take two number, and operate them
def sum(a,b): # parameters
    return a + b # return of a function

# %%
sum(20,80)

# Keyword Arguments
sum(b=30, a =100)
# Out:
# 130

# %% [markdown]
# ### Function Scope
# - global scope, function scope
# - Global variables --->
#     - can be *accessed anywhere* in the scipt
# - Local Variables --->
#     - defined *within the function scope*
#     -  can only be accessed within a function

# %%
scalar = 1000 # GLOBAL SCOPE

# take number of kilos ---> return how many grams are in them

def grams(kilos):
    result = kilos * scalar # FUNCTION SCOPE --- LOCAL SCOPE
    # local variable
    # print("i can see what result is: ", result)
    return result


grams(4)
# Out:
# 4000

# %% [markdown]
# - When a function RETURNS something, that return can be saved in a variable
# -

# %%
grams_in_56kg = grams(56)
print(grams_in_56kg)
# Out:
# 56000

# %% [markdown]
# #### Exercises:
# - Create a function that calculates factorial of a number n
# -
